# %%
#pip install lxml

# %%
from bs4 import BeautifulSoup
import pandas as pd
from scrapy.selector import Selector
import requests
from bs4 import BeautifulSoup

# %%
#dfbasedatos = pd.read_excel("BD SALUD AMBIENTAL.xlsx", sheet_name='Hoja1')

# %%
url = 'https://scienti.minciencias.gov.co/gruplac/jsp/visualiza/visualizagr.jsp?nro=00000000013302'

# %%
r = requests.get(url, verify=False)
soup = BeautifulSoup(r.text, 'lxml')
NomGrupo = soup.find("span", class_='celdaEncabezado')
NombreGrupo = NomGrupo.text
#Filtrar todas las tablas
table = soup.find_all('table')
df = pd.read_html(str(table))
#Numero de de tablas 
NumTablas = len(df)
#CICLO 
dfcon = pd.DataFrame()
dfcon["Nombre del Grupo"] = [NombreGrupo]
#Tabla numero 0, datos basicos, que es diferente 
#Tabla de datos 
df = pd.read_html(str(table))[0]
#Imputacion de los NAN
df= df.fillna('Sin dato')
#Tabla 1 
tamaño = df.shape
Nombre = df[0][0]
Dato = []
for j in range(1,tamaño[0]):
        Dato.append(df[0][j]+":  "+df[1][j]+"...   ")
Datos = " ".join(Dato)
Datos
dfcon[Nombre]= [Datos]
# Siguientes Tablas 1-12
for i in range (1,13):
    df = pd.read_html(str(table))[i]
    tamaño = df.shape
    Nombre = df[0][0]
    Datos = []
    for j in range(1,tamaño[0]):
            Datos.append(df[0][j])
    Datos = " ".join(Datos)
    dfcon[Nombre]= [Datos] 
#Tabla 13 -44 50-55
for i in range (13,45):
    df = pd.read_html(str(table))[i]
    tamaño = df.shape
    Nombre = df[0][0]
    Datos = []
    for j in range(1,tamaño[0]):
            Datos.append(df[1][j])
    Datos = " ".join(Datos)
    dfcon[Nombre]= [Datos]
#Table 45 - 46
for i in range (45,47):
    df = pd.read_html(str(table))[i]
    tamaño = df.shape
    Nombre = df[0][0]
    Datos = []
    for j in range(1,tamaño[0]-1):
            Datos.append(df[1][j])
    Datos = " ".join(Datos)
    dfcon[Nombre]= [Datos]
#Tabla 47 - 60 
for i in range (47,84):
    df = pd.read_html(str(table))[i]
    tamaño = df.shape
    Nombre = df[0][0]
    Datos = []
    for j in range(1,tamaño[0]):
            Datos.append(df[1][j])
    Datos = " ".join(Datos)
    dfcon[Nombre]= [Datos]
dfcon
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'scienti.minciencias.gov.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                                     Nombre del Grupo  \
# 0  BioTox - Grupo de Investigación en Biotecnolog...
#
#                                        Datos básicos  \
# 0  Año y mes de formación:  2011 - 9...    Depart...
#
#                                Instituciones  \
# 0  1.- UNIVERSIDAD DE LOS LLANOS - (Avalado)
#
#                                     Plan Estratégico  \
# 0  Plan de trabajo: El plan de trabajo proyectado...
#
#      Líneas de investigación declaradas por el grupo  \
# 0  1.- Salud ambiental 2.- Biología y fisiología ...
#
#                                Integrantes del grupo  \
# 0  Nombre 1.- Yohana María Velasco Santamaría 2.-...
#
#   PRODUCCIÓN DE FORMACIÓN Y EXTENSIÓN  \
# 0
#
#                      Programa académico de doctorado  \
# 0  1.- Programa académico: Doctorado en Ciencias ...
#
#   Programa académico de maestría Otro programa académico  ...  \
# 0                                                         ...
#
#   Participación Ciudadana en Proyectos de CTI  \
# 0
#
#            Producción en arte, arquitectura y diseño ACTIVIDADES DE FORMACIÓN  \
# 0  Obras o productos Industrias creativas y cultu...
#
#   Asesorías al Programa Ondas  \
# 0
#
#                     Curso de Corta Duración Dictados  \
# 0  1.- Otro : TALLER DE IMPLEMENTADORES EN BUENAS...
#
#                          Trabajos dirigidos/turorías  \
# 0  1.- Trabajos de grado de pregrado : Covid-19 -...
#
#   ACTIVIDADES COMO EVALUADOR  \
# 0
#
#    Jurado/Comisiones evaluadoras de trabajo de grado  \
# 0  1.- Pregrado : CALIDAD Y APTITUD QUESERA DE LA...
#
#               Participación en comités de evaluación Demás trabajos
# 0  1.- Acreditación de programas : Par Académico ...
#
# [1 rows x 85 columns]

# %% [markdown]
# # Generacion del JSON

# %%
result = dfcon.to_json(orient="split")

# %%
result
# Out:
# '{"columns":["Nombre del Grupo","Datos b\\u00e1sicos","Instituciones","Plan Estrat\\u00e9gico","L\\u00edneas de investigaci\\u00f3n declaradas por el grupo","Integrantes del grupo","PRODUCCI\\u00d3N DE FORMACI\\u00d3N Y EXTENSI\\u00d3N","Programa acad\\u00e9mico de doctorado","Programa acad\\u00e9mico de maestr\\u00eda","Otro programa acad\\u00e9mico","Curso de doctorado","Curso de maestr\\u00eda","Curso especializado de extensi\\u00f3n","PRODUCCI\\u00d3N BIBLIOGR\\u00c1FICA","Art\\u00edculos publicados","Libros publicados","Traducciones Filol\\u00f3gicas y Edici\\u00f3n de Fuentes","Cap\\u00edtulos de libro publicados","Documentos de trabajo","Otra publicaci\\u00f3n divulgativa","Otros art\\u00edculos publicados","Libros de formaci\\u00f3n","Libros de divulgaci\\u00f3n y\\/o Compilaci\\u00f3n de divulgaci\\u00f3n","Manuales y Gu\\u00edas Especializadas","Otros Libros publicados","Traducciones","Notas cient\\u00edficas","PRODUCCI\\u00d3N T\\u00c9CNICA Y TECNOL\\u00d3GICA","Cartas, mapas o similares","Conceptos t\\u00e9cnicos","Dise\\u00f1os industriales","Esquemas de trazados de circuito integrado","Informes t\\u00e9cnicos","Innovaciones en Procesos y Procedimientos","Innovaciones generadas en la Gesti\\u00f3n Empresarial","Nuevas variedades animal","Poblaciones mejoradas de razas pecuarias","Nuevas variedades vegetal","Nuevos registros cient\\u00edficos","Plantas piloto","Productos nutrac\\u00e9uticos","Otros productos tecnol\\u00f3gicos","Prototipos","Regulaciones y Normas","Protocolos de vigilancia epidemiol\\u00f3gica","Reglamentos t\\u00e9cnicos","Guias de pr\\u00e1ctica cl\\u00ednica","Proyectos de ley","Signos distintivos","Softwares","Empresas de base tecnol\\u00f3gica","APROPIACI\\u00d3N SOCIAL Y DIVULGACI\\u00d3N P\\u00daBLICA DE LA CIENCIA","Publicaciones editoriales no especializadas","Producciones de contenido digital - Audiovisual","Producciones de contenido digital - Sonoro","Producciones de contenido digital - Recursos gr\\u00e1ficos","Divulgaci\\u00f3n P\\u00fablica de la Ciencia producci\\u00f3n de estrategias y contenidos transmedia","Desarrollo web","Procesos de apropiaci\\u00f3n social del Conocimiento para el fortalecimiento o soluci\\u00f3n de asuntos de inter\\u00e9s social","Productos de apropiaci\\u00f3n social del conocimiento resultado del trabajo conjunto entre un Centro de Ciencia y un grupo de investigaci\\u00f3n","Proceso de Apropiaci\\u00f3n Social del Conocimiento para la generaci\\u00f3n de insumos de pol\\u00edtica p\\u00fablica y normatividad","Proceso de apropiaci\\u00f3n social del Conocimiento para el fortalecimiento de cadenas productivas","Consultor\\u00edas cient\\u00edfico-tecnol\\u00f3gicas","Ediciones","Eventos Cient\\u00edficos","Informes de investigaci\\u00f3n","Nuevas secuencias gen\\u00e9ticas","Redes de Conocimiento Especializado","Generaci\\u00f3nes de contenido de audio","Generaci\\u00f3n de Contenido Impreso","Generaci\\u00f3n de Contenido Multimedia","Generaci\\u00f3n de Contenido Virtual","Estrategias de Comunicaci\\u00f3n del Conocimiento","Estrategias Pedag\\u00f3gicas para el fomento a la CTI","Espacios de Participaci\\u00f3n Ciudadana","Participaci\\u00f3n Ciudadana en Proyectos de CTI","Producci\\u00f3n en arte, arquitectura y dise\\u00f1o","ACTIVIDADES DE FORMACI\\u00d3N","Asesor\\u00edas al Programa Ondas","Curso de Corta Duraci\\u00f3n Dictados","Trabajos dirigidos\\/turor\\u00edas","ACTIVIDADES COMO EVALUADOR","Jurado\\/Comisiones evaluadoras de trabajo de grado","Participaci\\u00f3n en comit\\u00e9s de evaluaci\\u00f3n","Dem\\u00e1s trabajos"],"index":[0],"data":[["BioTox - Grupo de Investigaci\\u00f3n en Biotecnolog\\u00eda y Toxicolog\\u00eda Acu\\u00e1tica y Ambiental","A\\u00f1o y mes de formaci\\u00f3n:  2011 - 9...    Departamento - Ciudad:  META - VILLAVICENCIO...    L\\u00edder:  Yohana Mar\\u00eda Velasco Santamar\\u00eda...    \\u00bfLa informaci\\u00f3n de este grupo se ha certificado?:  Si el d\\u00eda 2017-05-24...    P\\u00e1gina web:  Sin dato...  ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b93feba9-3c0b-4372-9ef7-200b9be1f561' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
